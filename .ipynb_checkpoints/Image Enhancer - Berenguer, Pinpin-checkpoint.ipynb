# %% [markdown]
# # Bulk Image Enhancer

# %% [markdown]
# **Authors:** Berenguer, Beatrice A. and Pinpin, Christopher Mari P. <br>
# **Section:** STDISCM - S13

# %% [markdown]
# In this project, we made a bulk image enhancer which will enhance all images from a source folder and will produce the enhanced photo to a destination folder. Stock photos will be used to populate the source folder and a folder named "enhanced" will be created to contain the enhanced photos.

# %% [markdown]
# In this section, `threading` will be imported to set the sempahore lock. We will set the `BoundedSemaphore` to a value of 5, so the program will only process 5 threads at a time. <br><br>
#
# To enhance the image, `Image` and `ImageEnhance` from `PIL` will be used to modify the contrast, brightness, and sharpness of the image.

# %%
from PIL import Image, ImageEnhance
import threading

semaphore = threading.BoundedSemaphore(value=5)
path = 'images/'
save_path = 'enhanced/'

def enhance_img(filename, c, b, s):
    print(filename + " is trying to access!")
    semaphore.acquire()
    
    print(filename + " granted access!")
    img = Image.open(path + filename)
    img_c = ImageEnhance.Contrast(img).enhance(c)
    img_b = ImageEnhance.Brightness(img_c).enhance(b)
    img_s = ImageEnhance.Sharpness(img_b).enhance(s)
    img_s.save(save_path + str(filename))
    
    print(filename + " is now releasing!")
    semaphore.release()

# %% [markdown]
# To modify the contrast, brightness, and sharpness, enter the enhancement factor for each. **Do note that an enhancement factor of 1 will return the original image without any enhancement.**

# %%
from os import listdir
import cv2
from matplotlib import pyplot as plt
import time


c = float(input('Contrast enhancement factor: '))
b = float(input('Brightness enhancement factor: '))
s = float(input('Sharpness enhancement factor: '))

start = time.time()
for img in listdir(path):
    enhance_img(img, c, b, s)
    
    
duration = time.time() - start
# Out:
# Contrast enhancement factor: 1.3
# Brightness enhancement factor: 0.7
# Sharpness enhancement factor: 1.7
# bird - Copy (10).jpg is trying to access!
# bird - Copy (10).jpg granted access!
# bird - Copy (10).jpg is now releasing!
# bird - Copy (11).jpg is trying to access!
# bird - Copy (11).jpg granted access!
# bird - Copy (11).jpg is now releasing!
# bird - Copy (12).jpg is trying to access!
# bird - Copy (12).jpg granted access!
# bird - Copy (12).jpg is now releasing!
# bird - Copy (13).jpg is trying to access!
# bird - Copy (13).jpg granted access!
# bird - Copy (13).jpg is now releasing!
# bird - Copy (2).jpg is trying to access!
# bird - Copy (2).jpg granted access!
# bird - Copy (2).jpg is now releasing!
# bird - Copy (3).jpg is trying to access!
# bird - Copy (3).jpg granted access!
# bird - Copy (3).jpg is now releasing!
# bird - Copy (4).jpg is trying to access!
# bird - Copy (4).jpg granted access!
# bird - Copy (4).jpg is now releasing!
# bird - Copy (5).jpg is trying to access!
# bird - Copy (5).jpg granted access!
# bird - Copy (5).jpg is now releasing!
# bird - Copy (6).jpg is trying to access!
# bird - Copy (6).jpg granted access!
# bird - Copy (6).jpg is now releasing!
# bird - Copy (7).jpg is trying to access!
# bird - Copy (7).jpg granted access!
# bird - Copy (7).jpg is now releasing!
# bird - Copy (8).jpg is trying to access!
# bird - Copy (8).jpg granted access!
# bird - Copy (8).jpg is now releasing!
# bird - Copy (9).jpg is trying to access!
# bird - Copy (9).jpg granted access!
# bird - Copy (9).jpg is now releasing!
# bird - Copy.jpg is trying to access!
# bird - Copy.jpg granted access!
# bird - Copy.jpg is now releasing!
# bird.jpg is trying to access!
# bird.jpg granted access!
# bird.jpg is now releasing!
# car - Copy (10).jpg is trying to access!
# car - Copy (10).jpg granted access!
# car - Copy (10).jpg is now releasing!
# car - Copy (11).jpg is trying to access!
# car - Copy (11).jpg granted access!
# car - Copy (11).jpg is now releasing!
# car - Copy (12).jpg is trying to access!
# car - Copy (12).jpg granted access!
# car - Copy (12).jpg is now releasing!
# car - Copy (13).jpg is trying to access!
# car - Copy (13).jpg granted access!
# car - Copy (13).jpg is now releasing!
# car - Copy (2).jpg is trying to access!
# car - Copy (2).jpg granted access!
# car - Copy (2).jpg is now releasing!
# car - Copy (3).jpg is trying to access!
# car - Copy (3).jpg granted access!
# car - Copy (3).jpg is now releasing!
# car - Copy (4).jpg is trying to access!
# car - Copy (4).jpg granted access!
# car - Copy (4).jpg is now releasing!
# car - Copy (5).jpg is trying to access!
# car - Copy (5).jpg granted access!
# car - Copy (5).jpg is now releasing!
# car - Copy (6).jpg is trying to access!
# car - Copy (6).jpg granted access!
# car - Copy (6).jpg is now releasing!
# car - Copy (7).jpg is trying to access!
# car - Copy (7).jpg granted access!
# car - Copy (7).jpg is now releasing!
# car - Copy (8).jpg is trying to access!
# car - Copy (8).jpg granted access!
# car - Copy (8).jpg is now releasing!
# car - Copy (9).jpg is trying to access!
# car - Copy (9).jpg granted access!
# car - Copy (9).jpg is now releasing!
# car - Copy.jpg is trying to access!
# car - Copy.jpg granted access!
# car - Copy.jpg is now releasing!
# car.jpg is trying to access!
# car.jpg granted access!
# car.jpg is now releasing!
# cat - Copy (10).jpg is trying to access!
# cat - Copy (10).jpg granted access!
# cat - Copy (10).jpg is now releasing!
# cat - Copy (11).jpg is trying to access!
# cat - Copy (11).jpg granted access!
# cat - Copy (11).jpg is now releasing!
# cat - Copy (12).jpg is trying to access!
# cat - Copy (12).jpg granted access!
# cat - Copy (12).jpg is now releasing!
# cat - Copy (13).jpg is trying to access!
# cat - Copy (13).jpg granted access!
# cat - Copy (13).jpg is now releasing!
# cat - Copy (2).jpg is trying to access!
# cat - Copy (2).jpg granted access!
# cat - Copy (2).jpg is now releasing!
# cat - Copy (3).jpg is trying to access!
# cat - Copy (3).jpg granted access!
# cat - Copy (3).jpg is now releasing!
# cat - Copy (4).jpg is trying to access!
# cat - Copy (4).jpg granted access!
# cat - Copy (4).jpg is now releasing!
# cat - Copy (5).jpg is trying to access!
# cat - Copy (5).jpg granted access!
# cat - Copy (5).jpg is now releasing!
# cat - Copy (6).jpg is trying to access!
# cat - Copy (6).jpg granted access!
# cat - Copy (6).jpg is now releasing!
# cat - Copy (7).jpg is trying to access!
# cat - Copy (7).jpg granted access!
# cat - Copy (7).jpg is now releasing!
# cat - Copy (8).jpg is trying to access!
# cat - Copy (8).jpg granted access!
# cat - Copy (8).jpg is now releasing!
# cat - Copy (9).jpg is trying to access!
# cat - Copy (9).jpg granted access!
# cat - Copy (9).jpg is now releasing!
# cat - Copy.jpg is trying to access!
# cat - Copy.jpg granted access!
# cat - Copy.jpg is now releasing!
# cat.jpg is trying to access!
# cat.jpg granted access!
# cat.jpg is now releasing!
# dog - Copy (10).jpg is trying to access!
# dog - Copy (10).jpg granted access!
# dog - Copy (10).jpg is now releasing!
# dog - Copy (11).jpg is trying to access!
# dog - Copy (11).jpg granted access!
# dog - Copy (11).jpg is now releasing!
# dog - Copy (12).jpg is trying to access!
# dog - Copy (12).jpg granted access!
# dog - Copy (12).jpg is now releasing!
# dog - Copy (13).jpg is trying to access!
# dog - Copy (13).jpg granted access!
# dog - Copy (13).jpg is now releasing!
# dog - Copy (2).jpg is trying to access!
# dog - Copy (2).jpg granted access!
# dog - Copy (2).jpg is now releasing!
# dog - Copy (3).jpg is trying to access!
# dog - Copy (3).jpg granted access!
# dog - Copy (3).jpg is now releasing!
# dog - Copy (4).jpg is trying to access!
# dog - Copy (4).jpg granted access!
# dog - Copy (4).jpg is now releasing!
# dog - Copy (5).jpg is trying to access!
# dog - Copy (5).jpg granted access!
# dog - Copy (5).jpg is now releasing!
# dog - Copy (6).jpg is trying to access!
# dog - Copy (6).jpg granted access!
# dog - Copy (6).jpg is now releasing!
# dog - Copy (7).jpg is trying to access!
# dog - Copy (7).jpg granted access!
# dog - Copy (7).jpg is now releasing!
# dog - Copy (8).jpg is trying to access!
# dog - Copy (8).jpg granted access!
# dog - Copy (8).jpg is now releasing!
# dog - Copy (9).jpg is trying to access!
# dog - Copy (9).jpg granted access!
# dog - Copy (9).jpg is now releasing!
# dog - Copy.jpg is trying to access!
# dog - Copy.jpg granted access!
# dog - Copy.jpg is now releasing!
# dog.jpg is trying to access!
# dog.jpg granted access!
# dog.jpg is now releasing!
# plane - Copy (10).jpg is trying to access!
# plane - Copy (10).jpg granted access!
# plane - Copy (10).jpg is now releasing!
# plane - Copy (11).jpg is trying to access!
# plane - Copy (11).jpg granted access!
# plane - Copy (11).jpg is now releasing!
# plane - Copy (12).jpg is trying to access!
# plane - Copy (12).jpg granted access!
# plane - Copy (12).jpg is now releasing!
# plane - Copy (13).jpg is trying to access!
# plane - Copy (13).jpg granted access!
# plane - Copy (13).jpg is now releasing!
# plane - Copy (2).jpg is trying to access!
# plane - Copy (2).jpg granted access!
# plane - Copy (2).jpg is now releasing!
# plane - Copy (3).jpg is trying to access!
# plane - Copy (3).jpg granted access!
# plane - Copy (3).jpg is now releasing!
# plane - Copy (4).jpg is trying to access!
# plane - Copy (4).jpg granted access!
# plane - Copy (4).jpg is now releasing!
# plane - Copy (5).jpg is trying to access!
# plane - Copy (5).jpg granted access!
# plane - Copy (5).jpg is now releasing!
# plane - Copy (6).jpg is trying to access!
# plane - Copy (6).jpg granted access!
# plane - Copy (6).jpg is now releasing!
# plane - Copy (7).jpg is trying to access!
# plane - Copy (7).jpg granted access!
# plane - Copy (7).jpg is now releasing!
# plane - Copy (8).jpg is trying to access!
# plane - Copy (8).jpg granted access!
# plane - Copy (8).jpg is now releasing!
# plane - Copy (9).jpg is trying to access!
# plane - Copy (9).jpg granted access!
# plane - Copy (9).jpg is now releasing!
# plane - Copy.jpg is trying to access!
# plane - Copy.jpg granted access!
# plane - Copy.jpg is now releasing!
# plane.jpg is trying to access!
# plane.jpg granted access!
# plane.jpg is now releasing!

# %%
print("Elapsed time: ", duration)
# Out:
# Elapsed time:  6.3804895877838135

# %% [markdown]
# The program was executed without the implementation of multithreading yet. With this, we can see that it enhanced each photo one by one. <br><br>
#
# Let's see the difference between the original image and the enhanced image.

# %%
path = 'images/'
save_path = 'enhanced/'

fig = plt.figure(figsize=(15, 20))

i = 1
columns = 2
rows = 1

for img in listdir(path):
    img_normal = cv2.imread(path + img)
    img_enhanced = cv2.imread(save_path + img)
    img_normal = cv2.cvtColor(img_normal, cv2.COLOR_BGR2RGB)
    img_enhanced = cv2.cvtColor(img_enhanced, cv2.COLOR_BGR2RGB)
    
    fig.add_subplot(rows, columns, i)
    plt.imshow(img_normal)
    plt.axis('off')
    plt.title('Original')
    i += 1
    
    fig.add_subplot(rows, columns, i)
    plt.imshow(img_enhanced)
    plt.axis('off')
    plt.title('Enhanced')
    i += 1
    if i == 3:
        break
    
plt.show()

# %% [markdown]
# We can see that the photo is clearly enhanced on the right. With this, let's implement multithreading and see how each thread gets access,  gets granted, and release the semaphore lock when enhancing a photo. <br><br>
#
# Let us also set a time limit in case the program runs for too long.

# %%
import threading

path = 'images/'
save_path = 'enhanced/'

end_time = int(input('Enter time duration (in seconds): '))


thread_ctr = 0
start_time = time.time()
for img in listdir(path):
    t = threading.Thread(target=enhance_img, args=(img, c, b, s,))
    t.start()
    thread_ctr += 1
    
    if end_time < time.time() - start_time:
        break
        
total_duration = time.time() - start_time
# Out:
# Enter time duration (in seconds): 5
# bird - Copy (10).jpg is trying to access!
# bird - Copy (10).jpg granted access!
# bird - Copy (11).jpg is trying to access!
# bird - Copy (11).jpg granted access!
# bird - Copy (12).jpg is trying to access!
# bird - Copy (12).jpg granted access!
# bird - Copy (13).jpg is trying to access!
# bird - Copy (13).jpg granted access!
# bird - Copy (2).jpg is trying to access!
# bird - Copy (2).jpg granted access!
# bird - Copy (3).jpg is trying to access!
# bird - Copy (4).jpg is trying to access!
# bird - Copy (5).jpg is trying to access!
# bird - Copy (6).jpg is trying to access!
# bird - Copy (10).jpg is now releasing!bird - Copy (11).jpg is now releasing!
#
# bird - Copy (7).jpg is trying to access!bird - Copy (3).jpg granted access!bird - Copy (12).jpg is now releasing!
#
#
# bird - Copy (7).jpg granted access!
# bird - Copy (4).jpg granted access!
# bird - Copy (8).jpg is trying to access!
# bird - Copy (9).jpg is trying to access!
# bird - Copy (2).jpg is now releasing!
# bird - Copy (6).jpg granted access!
# bird - Copy (13).jpg is now releasing!
# bird - Copy.jpg is trying to access!
# bird - Copy.jpg granted access!
# bird.jpg is trying to access!
# car - Copy (10).jpg is trying to access!
# bird - Copy (7).jpg is now releasing!
# bird - Copy (8).jpg granted access!
# bird - Copy (6).jpg is now releasing!
# bird - Copy (9).jpg granted access!
# bird - Copy (4).jpg is now releasing!
# bird - Copy (5).jpg granted access!
# bird - Copy.jpg is now releasing!
# car - Copy (10).jpg granted access!
# car - Copy (11).jpg is trying to access!bird - Copy (3).jpg is now releasing!
# bird.jpg granted access!
#
# car - Copy (12).jpg is trying to access!
# car - Copy (13).jpg is trying to access!
# car - Copy (2).jpg is trying to access!
# car - Copy (10).jpg is now releasing!
# car - Copy (12).jpg granted access!bird - Copy (8).jpg is now releasing!
#
# car - Copy (3).jpg is trying to access!
# car - Copy (3).jpg granted access!
# car - Copy (4).jpg is trying to access!
# bird - Copy (9).jpg is now releasing!
# car - Copy (13).jpg granted access!
# car - Copy (5).jpg is trying to access!
# car - Copy (12).jpg is now releasing!
# car - Copy (2).jpg granted access!
# bird - Copy (5).jpg is now releasing!
# car - Copy (11).jpg granted access!car - Copy (6).jpg is trying to access!
#
# car - Copy (13).jpg is now releasing!
# car - Copy (3).jpg is now releasing!car - Copy (4).jpg granted access!
#
# car - Copy (5).jpg granted access!
# car - Copy (11).jpg is now releasing!
# car - Copy (2).jpg is now releasing!
# car - Copy (6).jpg granted access!bird.jpg is now releasing!
#
# car - Copy (7).jpg is trying to access!
# car - Copy (7).jpg granted access!
# car - Copy (5).jpg is now releasing!
# car - Copy (4).jpg is now releasing!
# car - Copy (8).jpg is trying to access!
# car - Copy (9).jpg is trying to access!
# car - Copy (9).jpg granted access!
# car - Copy (8).jpg granted access!
# car - Copy (6).jpg is now releasing!
# car - Copy (7).jpg is now releasing!
# car - Copy (9).jpg is now releasing!
# car - Copy.jpg is trying to access!
# car - Copy (8).jpg is now releasing!car - Copy.jpg granted access!
#
# car.jpg is trying to access!
# cat - Copy (10).jpg is trying to access!
# cat - Copy (10).jpg granted access!
# car.jpg granted access!
# cat - Copy (11).jpg is trying to access!
# cat - Copy (11).jpg granted access!
# cat - Copy (12).jpg is trying to access!
# cat - Copy (12).jpg granted access!
# car - Copy.jpg is now releasing!
# car.jpg is now releasing!
# cat - Copy (13).jpg is trying to access!
# cat - Copy (13).jpg granted access!
# cat - Copy (2).jpg is trying to access!
# cat - Copy (2).jpg granted access!
# cat - Copy (3).jpg is trying to access!
# cat - Copy (4).jpg is trying to access!
# cat - Copy (5).jpg is trying to access!
# cat - Copy (6).jpg is trying to access!
# cat - Copy (7).jpg is trying to access!
# cat - Copy (12).jpg is now releasing!
# cat - Copy (8).jpg is trying to access!cat - Copy (3).jpg granted access!
#
# cat - Copy (9).jpg is trying to access!cat - Copy (11).jpg is now releasing!cat - Copy (13).jpg is now releasing!
# cat - Copy (10).jpg is now releasing!
#
# cat - Copy (4).jpg granted access!cat - Copy.jpg is trying to access!
#
#
# cat.jpg is trying to access!cat - Copy (5).jpg granted access!
# cat - Copy (6).jpg granted access!dog - Copy (10).jpg is trying to access!
#
#
# cat - Copy (2).jpg is now releasing!
# cat - Copy (7).jpg granted access!
# dog - Copy (11).jpg is trying to access!
# dog - Copy (12).jpg is trying to access!
# dog - Copy (13).jpg is trying to access!
# dog - Copy (2).jpg is trying to access!
# dog - Copy (3).jpg is trying to access!
# cat - Copy (3).jpg is now releasing!cat - Copy (5).jpg is now releasing!cat - Copy (6).jpg is now releasing!
#
#
# dog - Copy (4).jpg is trying to access!
# cat - Copy.jpg granted access!cat - Copy (9).jpg granted access!cat - Copy (8).jpg granted access!
#
#
# dog - Copy (5).jpg is trying to access!
# dog - Copy (6).jpg is trying to access!
# cat - Copy (4).jpg is now releasing!
# dog - Copy (10).jpg granted access!
# dog - Copy (7).jpg is trying to access!
# dog - Copy (8).jpg is trying to access!cat - Copy (7).jpg is now releasing!
# dog - Copy (9).jpg is trying to access!cat.jpg granted access!
#
#
# dog - Copy (10).jpg is now releasing!
# dog - Copy.jpg is trying to access!dog - Copy (12).jpg granted access!
#
# dog.jpg is trying to access!
# dog - Copy (12).jpg is now releasing!
# dog - Copy (11).jpg granted access!
# plane - Copy (10).jpg is trying to access!
# plane - Copy (11).jpg is trying to access!
# cat - Copy.jpg is now releasing!
# dog - Copy (13).jpg granted access!plane - Copy (12).jpg is trying to access!
# cat - Copy (8).jpg is now releasing!cat - Copy (9).jpg is now releasing!
#
#
# dog - Copy (2).jpg granted access!
# dog - Copy (3).jpg granted access!plane - Copy (13).jpg is trying to access!
#
# plane - Copy (2).jpg is trying to access!
# plane - Copy (3).jpg is trying to access!
# dog - Copy (11).jpg is now releasing!
# dog - Copy (4).jpg granted access!
# plane - Copy (4).jpg is trying to access!
# plane - Copy (5).jpg is trying to access!
# plane - Copy (6).jpg is trying to access!
# dog - Copy (3).jpg is now releasing!
# dog - Copy (4).jpg is now releasing!
# dog - Copy (5).jpg granted access!
# dog - Copy (2).jpg is now releasing!
# dog - Copy (6).jpg granted access!
# dog - Copy (7).jpg granted access!
# plane - Copy (7).jpg is trying to access!
# dog - Copy (13).jpg is now releasing!
# dog - Copy (9).jpg granted access!
# plane - Copy (8).jpg is trying to access!
# dog - Copy (5).jpg is now releasing!
# dog - Copy (8).jpg granted access!
# cat.jpg is now releasing!
# dog - Copy (6).jpg is now releasing!
# dog - Copy.jpg granted access!plane - Copy (9).jpg is trying to access!dog.jpg granted access!
#
#
# dog - Copy (7).jpg is now releasing!
# plane - Copy (10).jpg granted access!
# plane - Copy.jpg is trying to access!
# dog - Copy (9).jpg is now releasing!
# plane - Copy (11).jpg granted access!
# plane.jpg is trying to access!
# dog - Copy (8).jpg is now releasing!
# plane - Copy (12).jpg granted access!
# dog - Copy.jpg is now releasing!
# plane - Copy (13).jpg granted access!plane - Copy (11).jpg is now releasing!dog.jpg is now releasing!
#
#
# plane - Copy (2).jpg granted access!
# plane - Copy (3).jpg granted access!
# plane - Copy (10).jpg is now releasing!
# plane - Copy (4).jpg granted access!
# plane - Copy (12).jpg is now releasing!
# plane - Copy (13).jpg is now releasing!plane - Copy (2).jpg is now releasing!
#
# plane - Copy (5).jpg granted access!
# plane - Copy (7).jpg granted access!plane - Copy (6).jpg granted access!
#
# plane - Copy (3).jpg is now releasing!
# plane - Copy (8).jpg granted access!
# plane - Copy (4).jpg is now releasing!
# plane - Copy (9).jpg granted access!
# plane - Copy (5).jpg is now releasing!
# plane - Copy.jpg granted access!
# plane - Copy (8).jpg is now releasing!
# plane - Copy (7).jpg is now releasing!
# plane.jpg granted access!
# plane - Copy (9).jpg is now releasing!
# plane - Copy.jpg is now releasing!
# plane - Copy (6).jpg is now releasing!
# plane.jpg is now releasing!

# %%
print("Total elapsed time: ", total_duration)
print("Total images enhanced: ", thread_ctr)
# Out:
# Total elapsed time:  2.3526816368103027
# Total images enhanced:  70

# %% [markdown]
# The total elapsed time drastically improved when multithreading and semaphore is implemented. By having a `BoundedSemaphore` with a value of 5, it allowed threads to execute simultaneously and decrease the time completion to enhance all photos.
